# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
import GrafOpt as go

# %%
x,y=np.loadtxt('C:/Users/Yovanni/Downloads/Regresion lineal/IR1.txt',unpack=True);

G=go.RL(x,y);
print(G);

xi=x[0];
xf=x[-1];

X=np.zeros(101);
Y=np.zeros(101);
dx=(xf-xi)/100;

for i in range(0,101):
    X[i]=xi+i*dx;
    Y[i]=go.f(X[i],G[0],G[1]);

fig, ax = plt.subplots();
ax.plot(x,y,'co');
ax.plot(X,Y,'r-');
ax.set_title('Gráfica del ángulo de reflexión, interfaz aire-vidrio')
L=[r'$Observación$', r'$Ajuste \ lineal: \theta_i=\theta_r$']
ax.legend(L)
ax.set_xlabel(r"$\theta_r \ (^\circ)$", fontsize=15, fontname='Times New Roman')
ax.set_ylabel(r"$\theta_i \ (^\circ)$", fontsize=15, fontname='Times New Roman')
plt.grid();
plt.show()

# %%
y,x=np.loadtxt('C:/Users/Yovanni/Downloads/Regresion lineal/IT1.txt',unpack=True);
N=np.size(x);

sx=np.zeros(N);
sy=np.zeros(N);

for i in range(0,N):
    sx[i]=np.sin((np.pi/180)*x[i]);
    sy[i]=np.sin((np.pi/180)*y[i]);

G=go.RL(sx,sy);
print(G);
xi=sx[0];
xf=sx[-1];

X=np.zeros(101);
Y=np.zeros(101);
dx=(xf-xi)/100;

for i in range(0,101):
    X[i]=xi+i*dx;
    Y[i]=go.f(X[i],G[0],G[1]);

fig, ax = plt.subplots();
ax.plot(sx,sy,'co');
ax.plot(X,Y,'r-');
ax.set_title('Gráfica del seno del ángulo de refracción, interfaz aire-vidrio')
L=[r'$Observación$', r'$Ajuste \ lineal: \ sen(\theta_i)=(1.4939)sen(\theta_t)-0.0023$']
ax.legend(L)
ax.set_xlabel(r"$sen(\theta_t) \ (^\circ)$", fontsize=15, fontname='Times New Roman')
ax.set_ylabel(r"$sen(\theta_i) \ (^\circ)$", fontsize=15, fontname='Times New Roman')
plt.grid();
plt.show()
# Out:
# [1.493851884492774, -0.002335366833142579, 0.015065664101783924, 0.006252130328163405]

# %%
x,y=np.loadtxt('C:/Users/Yovanni/Downloads/Regresion lineal/IR2.txt',unpack=True);

G=go.RL(x,y);
print(G);

xi=x[0];
xf=x[-1];

X=np.zeros(101);
Y=np.zeros(101);
dx=(xf-xi)/100;

for i in range(0,101):
    X[i]=xi+i*dx;
    Y[i]=go.f(X[i],G[0],G[1]);

fig, ax = plt.subplots();
ax.plot(x,y,'co');
ax.plot(X,Y,'r-');

ax.set_title('Gráfica del ángulo de reflexión, interfaz vidrio-aire')
L=[r'$Observación$', r'$Ajuste \ lineal: \theta_i=\theta_r$']
ax.legend(L)
ax.set_xlabel(r"$\theta_r \ (^\circ)$", fontsize=15, fontname='Times New Roman')
ax.set_ylabel(r"$\theta_i \ (^\circ)$", fontsize=15, fontname='Times New Roman')
plt.grid();
plt.show()

# %%
x,y=np.loadtxt('C:/Users/Yovanni/Downloads/Regresion lineal/IT2.txt',unpack=True);

N=np.size(x);

sx=np.zeros(N);
sy=np.zeros(N);

for i in range(0,N):
    sx[i]=np.sin((np.pi/180)*x[i]);
    sy[i]=np.sin((np.pi/180)*y[i]);

G=go.RL(sx,sy);
print(G);
xi=sx[0];
xf=sx[-1];
X=np.zeros(101);
Y=np.zeros(101);
dx=(xf-xi)/100;

for i in range(0,101):
    X[i]=xi+i*dx;
    Y[i]=go.f(X[i],G[0],G[1]);


fig, ax = plt.subplots();
ax.plot(sx,sy,'co');
ax.plot(X,Y,'r-');
ax.set_title('Gráfica del seno del ángulo de refracción, interfaz vidrio-aire')
L=[r'$Observación$', r'$Ajuste \ lineal: \ sen(\theta_i)=(1.5333)sen(\theta_t)-0.0141$']
ax.legend(L)
ax.set_xlabel(r"$sen(\theta_t) \ (^\circ)$", fontsize=15, fontname='Times New Roman')
ax.set_ylabel(r"$sen(\theta_i) \ (^\circ)$", fontsize=15, fontname='Times New Roman')
plt.grid();
plt.show()
# Out:
# [1.5332531657594657, -0.014077191977813739, 0.02251744859467178, 0.010157985343146266]
